# %%
import os
import re
from io import BytesIO

import pandas as pd
import requests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
from itables import init_notebook_mode
from pypdf import PdfWriter, PdfReader

from urllib.parse import urlsplit

init_notebook_mode(all_interactive=True)
# Out:
# <script>
#   // Create a pending promise immediately (this script is not deferred).
#   window.dataTablePromise = new Promise((resolve) => {
#     window.__resolveDataTablePromise__ = resolve;
#   });
# </script>
# <script type="module">
#   // Module scripts are automatically deferred, so this code will not execute immediately.
#   // See https://developer.mozilla.org/en-US/docs/Web/JavaScript/Guide/Modules#other_differences_between_modules_and_standard_scripts
#   if ($.prototype.DataTable === undefined) {
#       const dt = (await import("data:text/javascript;base64,...")).default;
#       dt(window.$);
#       // Resolve the pending promise above, indicating that DataTable is now ready to be used.
#       window.__resolveDataTablePromise__();
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %% [markdown]
# ### Webscraping functions

# %%
ua = UserAgent(min_percentage=2.1)
ua.random
headers = {'User-Agent': str(ua.random)}

# %%
def is_url(cell):
    return bool(re.match("^https://", cell))

def get_url_content(domain):
    links = []
    if is_url(domain):
        # print(domain)
        headers = {'User-Agent': str(ua.random)}
        response = requests.get(domain, headers=headers)
        # print(response.url)
        soup = BeautifulSoup(response.text, 'lxml')
        if bool(re.match("^https://cgspace.cgiar.org/handle/", response.url)):
            # if there are any pdfs on the page directly access them - https://cgspace.cgiar.org/handle/10568/126321; https://cgspace.cgiar.org/handle/10568/116411; https://cgspace.cgiar.org/handle/10568/121051
            links.extend([a['href'] for a in soup.find_all('a', {'href': re.compile(".*\.pdf$")})])
            # files on Github - ex. https://hdl.handle.net/10568/127746
            if len(links) == 0:
                links.extend(meta['content'] for meta in soup.find_all('meta', {'name': re.compile("citation_(pdf|abstract)_url")}))
            if len(links) == 0:
                hrefs = [a['href'] for a in soup.find_all('a', href=True)]
                for href in hrefs:
                    if href.startswith("https://doi.org/"):
                        response = requests.get(href, headers=headers)
                        url = response.url
                        response = requests.get(url, headers=headers)
                        soup = BeautifulSoup(response.text, 'lxml')
                        if bool(re.match("^https://academic.oup.com/wber/article/", response.url)):
                            links.extend(meta['content'] for meta in soup.find_all('meta', {'name': re.compile("citation_(pdf|abstract)_url")}))
                        elif bool(re.match("^https://link.springer.com/article/", response.url)):
                            links.extend(meta['content'] for meta in soup.find_all('meta', {'name': re.compile("citation_(pdf|abstract)_url")}))
                        elif bool(re.match("^https://gh.bmj.com/content/", response.url)):
                            links.extend(meta['content'] for meta in soup.find_all('meta', {'name': re.compile("citation_(pdf|abstract)_url")}))
                        # elif bool(re.match("^https://linkinghub.elsevier.com/retrieve/pii/", response.url)):
                        #     print("Science Direct")
                        #     _url = response.url
                        #     id = _url.split("/")[-1]
                        #     response = requests.get(url = f"https://www.sciencedirect.com/science/article/pii/{id}", headers=headers)
                        #     anchor = soup.find('a', {'href': lambda x: x.startswith('https://www.sciencedirect.com/science/article/pii/')})
                        #     print(anchor)
                        #     # doc_id =
                        #     # links.extend([f"https://www.sciencedirect.com/science/article/pii/{doc_id}.pdf"])
                    elif href.startswith("https://www.iwmi.cgiar.org/"):
                        links.extend([href])
                    else:
                        continue
        else:
            print(f"Error: {response.url}. Unable to find a PDF file link.")
        if len(links) > 0:
            return "".join(links)
        else:
            return pd.NA

# still in development - if https://doi.org/ redirects to https://www.sciencedirect.com/ then scrape https://www.sciencedirect.com/[...]-main.pdf - https://doi.org/10.1016/j.ehb.2022.101185, https://doi.org/10.1016/j.pce.2021.103082
# still in development - if https://doi.org/ redirects to https://www.cambridge.org/core/journals/ then scrape https://www.cambridge.org/core/services/aop-cambridge-core/content/view/[...].pdf

# %% [markdown]
# ### 2022 Innovation Development Document

# %%
df = pd.read_excel("/Users/.../file_1698742987140.xlsx")

# %% [markdown]
# The original file contain 477 records.

# %% [markdown]
# #### Get direct URL to evidence and save to updated document

# %%
df["Evidence 1"] = df["Evidence 1"].astype(str)
df["Evidence 2"] = df["Evidence 2"].astype(str)
df["Evidence 3"] = df["Evidence 3"].astype(str)

# %%
df_filtered = df[df['Evidence 1'].apply(is_url) | df['Evidence 2'].apply(is_url) | df['Evidence 3'].apply(is_url)]

# %% [markdown]
# Only 126 of these records contains at least 1 link for one of the three fields: 'Evidence 1', 'Evidence 2', 'Evidence 3'.

# %%
df_filtered
# Out:
#      Result id                                           PDF link  \
# 2         1099  https://reporting.cgiar.org/reports/result-det...
# 15        1036  https://reporting.cgiar.org/reports/result-det...
# 21        2897  https://reporting.cgiar.org/reports/result-det...
# 28        2793  https://reporting.cgiar.org/reports/result-det...
# 29        1031  https://reporting.cgiar.org/reports/result-det...
# ..         ...                                                ...
# 460       1593  https://reporting.cgiar.org/reports/result-det...
# 461       1489  https://reporting.cgiar.org/reports/result-det...
# 465       1026  https://reporting.cgiar.org/reports/result-det...
# 472       1100  https://reporting.cgiar.org/reports/result-det...
# 474        805  https://reporting.cgiar.org/reports/result-det...
#
#     Primary submitter              Level                    Type  \
# 2             INIT-17  Initiative output  Innovation development
# 15            INIT-34  Initiative output  Innovation development
# 21            INIT-22  Initiative output  Innovation development
# 28            INIT-03  Initiative output  Innovation development
# 29            INIT-34  Initiative output  Innovation development
# ..                ...                ...                     ...
# 460           INIT-25  Initiative output  Innovation development
# 461           INIT-25  Initiative output  Innovation development
# 465           INIT-28  Initiative output  Innovation development
# 472           INIT-34  Initiative output  Innovation development
# 474           INIT-21  Initiative output  Innovation development
#
#                                                  Title  \
# 2    Integrated-approach with Public Private Partne...
# 15   An improved framework for cost benefit analysi...
# 21   Vitamin A rich banana adoption in Cibitoke and...
# 28   Conservation methods developed for rare wild b...
# 29   Agri-climate risk scoring system for livestock...
# ..                                                 ...
# 460  High-frequency diet quality data collection an...
# 461  Biomass Climate Adaptation Index (CAI): A sate...
# 465  New Water Storage Diagnostic to diversify and ...
# 472  Multidsciplinary working group (MWG) as a dedi...
# 474  Through this initiative, farmers receive key c...
#
#                                            Description  \
# 2    "In Mali, vaccination campaigns against major ...
# 15   A framework(s) for improving large-scale land ...
# 21   A positive perception was observed among farme...
# 28   A rare bean species, Phaseolus hygrophilus, wh...
# 29   A satellite-based agri-climate risk scoring sy...
# ..                                                 ...
# 460  CGIAR Research Initiative on Digital Innovatio...
# 461  The lack of systematic tools and approaches fo...
# 465  The Water Storage Diagnostic is an approach to...
# 472  The multidisciplinary working group (MWG) is a...
# 474  Shamba shape is a farm makeover show which rea...
#
#                                    Lead contact person      Gender level  \
# 2                                         Michel Dione   (1) Significant
# 15                   Fiona Flintan f.flintan@cgiar.org  (0) Not targeted
# 21   Walter Ocimati, w.ocimati@cgiar.org, 46-Allian...  (0) Not targeted
# 28                                         Peter Wenzl  (0) Not targeted
# 29   Shalika Yvas, s.vyas@cgiar.org, Alliance Biove...   (1) Significant
# ..                                                 ...               ...
# 460                                 Rhys Manners, IITA   (1) Significant
# 461  Louis Reymondin, The Alliance of Bioversity In...  (0) Not targeted
# 465                                    Jonathan Lautze  (0) Not targeted
# 472                                     Issa Ouedraogo  (0) Not targeted
# 474                                     Pedro Chilambe   (1) Significant
#
#     Climate change level  ... Is new variety?  number_of_varieties  \
# 2       (0) Not targeted  ...  Not applicable                  NaN
# 15      (0) Not targeted  ...  Not applicable                  NaN
# 21      (0) Not targeted  ...              No                  NaN
# 28      (0) Not targeted  ...              No                  NaN
# 29       (1) Significant  ...  Not applicable                  NaN
# ..                   ...  ...             ...                  ...
# 460     (0) Not targeted  ...              No                  NaN
# 461        (2) Principal  ...              No                  NaN
# 465      (1) Significant  ...  Not applicable                  NaN
# 472        (2) Principal  ...  Not applicable                  NaN
# 474        (2) Principal  ...  Not applicable                  NaN
#
#                                             Developers  \
# 2                 Michel Dione m.dione@cgiar.org, ILRI
# 15      Fiona Flintan, ILRI  f.flintan@cgiar.org, ILRI
# 21   Walter Ocimati, w.ocimati@cgiar.org, 46-Allian...
# 28                                                 NaN
# 29   Shalika Yvas, s.vyas@cgiar.org, Alliance Biove...
# ..                                                 ...
# 460            Rhys Manners, r.manners@cgiar.org, IITA
# 461  Louis Reymondin, l.reymondin@cgiar.org, The Al...
# 465        Jonathan Lautze <j.lautze@cgiar.org> - IWMI
# 472  Issa Ouedraogo, i.ouedraogo@cgiar.org, Allianc...
# 474  Pedro Chilambe, p.chilambe@cgiar.org, Alliance...
#
#                                          Collaborators  \
# 2    Abdou Fall, ILRI\nAhmadou Sow, ILRI\nIbrahima ...
# 15                                                 NaN
# 21   Saidi Bizoza, b.s.bizoza@gmail.com, 1496-Insti...
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 460  Julius Adewopo, j.adewopo@cgiar.org, IITA\nAnn...
# 461  Aaron Golden, aaron.golden@universityofgalway....
# 465  Dhyey Bhatpuria <D.Bhatpuria@cgiar.org> IWMI\n...
# 472                                                NaN
# 474  Evan Girvetz, e.girvetz@cgiar.org, Alliance Bi...
#
#                                        Acknowledgement Readiness level  \
# 2                                                  NaN               6
# 15                                                 NaN               1
# 21                                                 NaN               8
# 28                                                 NaN               6
# 29                                                 NaN               0
# ..                                                 ...             ...
# 460  The Rockefeller Foundation\nUnited States Agen...               7
# 461  The University of Galway received funds from t...               3
# 465  US State Department project: Built Water Stora...               2
# 472                              USAID, ICRASAT, CCAFS               9
# 474                             World Bank and AICCRA.               9
#
#                                  Evidences explanation  \
# 2    "In general, IPs have facilitated access to an...
# 15   Research is being undertaken to develop princi...
# 21   The innovation is being tested for its ability...
# 28   The new successful protocols are reported in t...
# 29   We choose level 0 for this innovation, as the ...
# ..                                                 ...
# 460  We chose readiness level 7 (prototype) for the...
# 461  We chose readiness level 3 (proof of concept) ...
# 465  We chose level 2 because the innovation has be...
# 472  We chose innovation readiness evel 9 (proven i...
# 474  SSU aims to raise knowledge of good farming an...
#
#                                         Evidence 1  \
# 2    https://cgspace.cgiar.org/handle/10568/105820
# 15   https://cgspace.cgiar.org/handle/10568/127891
# 21             https://hdl.handle.net/10568/127269
# 28              https://hdl.handle.net/10568/83271
# 29   https://cgspace.cgiar.org/handle/10568/121675
# ..                                             ...
# 460            https://hdl.handle.net/10568/125562
# 461  https://cgspace.cgiar.org/handle/10568/126091
# 465            https://hdl.handle.net/10568/126486
# 472  https://cgspace.cgiar.org/handle/10568/117375
# 474  https://cgspace.cgiar.org/handle/10568/126423
#
#                                         Evidence 2 Evidence 3
# 2                                              nan        nan
# 15                                             nan        nan
# 21                                             nan        nan
# 28                                             nan        nan
# 29                                             nan        nan
# ..                                             ...        ...
# 460                                            nan        nan
# 461  https://cgspace.cgiar.org/handle/10568/127239        nan
# 465            https://hdl.handle.net/10568/127440        nan
# 472                                            nan        nan
# 474                                            nan        nan
#
# [126 rows x 40 columns]

# %% [markdown]
# #### Test Webscraping functions

# %%
cell = "https://cgspace.cgiar.org/handle/10568/121051"

output = get_url_content(cell)
print(output)
# Out:
# https://www.iwmi.cgiar.org/tools/sip-sizing-tool/sip_sizing_manual.pdf

# %%
url = "https://cgspace.cgiar.org/bitstream/10568/127891/2/CBA_Silestri.pdf"
headers = {'User-Agent': str(ua.random)}
response = requests.get(url, headers=headers)

print(response.status_code)

if response.status_code == 200:
    pdf_data = response.content
    with open("/Users/.../data/2897/CBA_Silestri.pdf", "wb") as f:
        f.write(pdf_data)
else:
    print("Error: Unable to download PDF file.")
# Out:
# 200

# %%
response = requests.get('https://api.reporting.cgiar.org/api/platform-report/result/32?phase=1')

if response.status_code == 200:
    # Read the PDF data from the response content
    pdf_reader = PdfReader(BytesIO(response.content))

    with open("/Users/.../2022/32/result.pdf", "wb") as f:
        pdf_writer = PdfWriter()
        for page in pdf_reader.pages:
            pdf_writer.add_page(page)
        pdf_writer.write(f)

# %% [markdown]
# #### Get direct URL to evidence and save to updated document

# %%
df_updated = df_filtered.copy()
df_updated.loc[:, 'Evidence 1 Links'] = df_filtered['Evidence 1'].apply(get_url_content)
df_updated.loc[:, 'Evidence 2 Links'] = df_filtered['Evidence 2'].apply(get_url_content)
df_updated.loc[:, 'Evidence 3 Links'] = df_filtered['Evidence 3'].apply(get_url_content)
# Out:
# /Users/ebenge/mambaforge/envs/ai/lib/python3.11/site-packages/bs4/builder/__init__.py:545: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   warnings.warn(

# %%
df_updated.to_excel("/Users/.../evidence_links_file_1698742987140_v2.xlsx")

# %% [markdown]
# #### Read in updated 2022 Innovation Development Document

# %%
df_updated = pd.read_excel("/Users/.../evidence_links_file_1698742987140_v2.xlsx")

# %%
print(df_updated.columns)
# Out:
# Index(['Unnamed: 0', 'Result id', 'PDF link', 'Primary submitter', 'Level',
#        'Type', 'Title', 'Description', 'Lead contact person', 'Gender level',
#        'Climate change level', 'Actors', 'Is KRS', 'KRS link',
#        'From previous portfolio', 'Legacy ID', 'Contributing initiatives',
#        'Non pooled projects', 'Primary center', 'Contributing centers',
#        'TOC results', 'Action areas', 'Impact areas', 'toc_sdgs', 'Partners',
#        'Countries', 'Regions', 'Linked results', 'Short title',
#        'Innovation characterization', 'Innovation nature', 'Is new variety?',
#        'number_of_varieties', 'Developers', 'Collaborators', 'Acknowledgement',
#        'Readiness level', 'Evidences explanation', 'Evidence 1', 'Evidence 2',
#        'Evidence 3', 'Evidence 1 Links', 'Evidence 2 Links',
#        'Evidence 3 Links'],
#       dtype='object')

# %% [markdown]
# ### Download Result PDFs

# %%
df_view = df_updated.loc[:, ['Result id', 'PDF link']]
df_view
# Out:
#      Result id                                           PDF link
# 0         1099  https://reporting.cgiar.org/reports/result-det...
# 1         1036  https://reporting.cgiar.org/reports/result-det...
# 2         2897  https://reporting.cgiar.org/reports/result-det...
# 3         2793  https://reporting.cgiar.org/reports/result-det...
# 4         1031  https://reporting.cgiar.org/reports/result-det...
# ..         ...                                                ...
# 121       1593  https://reporting.cgiar.org/reports/result-det...
# 122       1489  https://reporting.cgiar.org/reports/result-det...
# 123       1026  https://reporting.cgiar.org/reports/result-det...
# 124       1100  https://reporting.cgiar.org/reports/result-det...
# 125        805  https://reporting.cgiar.org/reports/result-det...
#
# [126 rows x 2 columns]

# %%
root = "/Users/.../2022/"

for index, row in df_view.iterrows():
    id = row['Result id']

    path = f"{root}/{id}"
    if not os.path.exists(path):
        os.makedirs(path)

    if id not in (754, 999, 1783, 28, 1003, 35, 455) :  # results not available on PRMS
        response = requests.get(f"https://api.reporting.cgiar.org/api/platform-report/result/{id}?phase=1")

        if response.status_code == 200:
            pdf_reader = PdfReader(BytesIO(response.content))

            with open(f"/Users/.../2022/{id}/result.pdf", "wb") as f:
                pdf_writer = PdfWriter()
                for page in pdf_reader.pages:
                    pdf_writer.add_page(page)
                pdf_writer.write(f)
            print(f"Successfully downloaded result.pdf for Result ID {id}")
        else:
            print(f"Error: Unable to download result.pdf for Result ID {id}")
# Out:
# Successfully downloaded result.pdf for Result ID 1099
# Successfully downloaded result.pdf for Result ID 1036
# Successfully downloaded result.pdf for Result ID 2171
# Successfully downloaded result.pdf for Result ID 1124
# Successfully downloaded result.pdf for Result ID 856
# Error: Unable to download result.pdf for Result ID 1922
# Successfully downloaded result.pdf for Result ID 1698
# Successfully downloaded result.pdf for Result ID 1787
# Successfully downloaded result.pdf for Result ID 128
# Successfully downloaded result.pdf for Result ID 3419
# Successfully downloaded result.pdf for Result ID 3856
# Successfully downloaded result.pdf for Result ID 1131
# Successfully downloaded result.pdf for Result ID 1102
# Successfully downloaded result.pdf for Result ID 3155
# Successfully downloaded result.pdf for Result ID 891
# Successfully downloaded result.pdf for Result ID 274
# Successfully downloaded result.pdf for Result ID 3724
# Successfully downloaded result.pdf for Result ID 3037
# Successfully downloaded result.pdf for Result ID 3145
# Successfully downloaded result.pdf for Result ID 2182
# Successfully downloaded result.pdf for Result ID 2097
# Successfully downloaded result.pdf for Result ID 2933
# Successfully downloaded result.pdf for Result ID 2966
# Successfully downloaded result.pdf for Result ID 3341
# Successfully downloaded result.pdf for Result ID 782
# Successfully downloaded result.pdf for Result ID 32
# Successfully downloaded result.pdf for Result ID 34
# Successfully downloaded result.pdf for Result ID 45
# Successfully downloaded result.pdf for Result ID 4136
# Successfully downloaded result.pdf for Result ID 236
# Successfully downloaded result.pdf for Result ID 953
# Successfully downloaded result.pdf for Result ID 3359
# Successfully downloaded result.pdf for Result ID 1296
# Successfully downloaded result.pdf for Result ID 1038
# Successfully downloaded result.pdf for Result ID 1005
# Successfully downloaded result.pdf for Result ID 3074
# Successfully downloaded result.pdf for Result ID 3018
# Successfully downloaded result.pdf for Result ID 4141
# Successfully downloaded result.pdf for Result ID 309
# Successfully downloaded result.pdf for Result ID 1106
# Successfully downloaded result.pdf for Result ID 791
# Successfully downloaded result.pdf for Result ID 2104
# Successfully downloaded result.pdf for Result ID 2117
# Successfully downloaded result.pdf for Result ID 4273
# Successfully downloaded result.pdf for Result ID 1593
# Successfully downloaded result.pdf for Result ID 1489
# Successfully downloaded result.pdf for Result ID 1026
# Successfully downloaded result.pdf for Result ID 1100
# Successfully downloaded result.pdf for Result ID 805

# %% [markdown]
# ### Download Evidence PDFs

# %%
def get_filename(link):
    return os.path.splitext(os.path.basename(urlsplit(link)[2]))[0]

def download_evidence(root, row):
    exclusion = ['https://cgspace.cgiar.org/bitstream/10568/126881/1/Reporte_CETC-IL_Intibuc%c3%a1_2022.pdf']
    links = []
    id = row['Result id']
    path = f"{root}/{id}"
    if not os.path.exists(path):
        os.makedirs(path)
    for col in ['Evidence 1 Links', 'Evidence 2 Links', 'Evidence 3 Links']:
        if isinstance(row[col], str) and row[col] not in exclusion:
            links.append(row[col])
    for link in links:
        print("url: ", link)
        fname = get_filename(link)
        response = requests.get(link, headers=headers)
        print("response code: ", response.status_code)
        if response.status_code == 200:
            data = response.content
            if os.path.splitext(os.path.basename(urlsplit(link)[2]))[0] == ".pdf":
                with open(f"{path}/{fname}.pdf", 'wb') as f:
                    f.write(data)
            elif os.path.splitext(os.path.basename(urlsplit(link)[2]))[0] == ".pptx":
                with open(f"{path}/{fname}.pptx", 'wb') as f:
                    f.write(data)
        else:
            print(f"Error: Unable to download {fname}.pdf")

# %%
print(os.path.splitext(os.path.basename(urlsplit("https://cgspace.cgiar.org/bitstream/10568/127872/1/AAEA_aug_022.pptx")[2]))[1])
# Out:
# .pptx

# %%
root = "/Users/.../2022"
df_updated.apply(lambda x: download_evidence(root, x), axis=1)
# Out:
# url:  https://cgspace.cgiar.org/bitstream/10568/127891/2/CBA_Silestri.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/
pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/120171/1/journal%20article.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/118287/1/InnovationBrief_SRM_dec2021.pdf
# response code:  200
# url:  https://www.sciencedirect.com/science/article/pii/S147470652100125X/pdfft?md5=59bd7a98182c33a44b62aaf447495217&pid=1-s2.0-S147470652100125X-main.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/109075/5/eco_ppr_toolbox%20.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/109076/5/eco_ppr_en.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/126019/1/market%20intelligence%20brief.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/128238/5/65969.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127243/1/report.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/128170/1/A%20ML-protocol%20for%20measuring%20CBB%20disease%20progression.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/handle/10568/128177/Validation_of_AI%20web_tool_for_CMD.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127948/2/d4d45a1015645dced2601197148681bd.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/128005/2/c9f1cceecd33f93443b172d09760c5e5.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127261/1/ifpridp02158.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/handle/10568/109736/CCAFS%20-%20Compendium%20Solar_Final.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/103725/1/Final%20chakhaji%20March%202019.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127640/2/8aa2bc255b635e9acf05a17115f070af.pdf
# response code:  200
# url:  https://www.publish.csiro.au/an/acc/AN17809/AN17809_AC.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/108788/1/Manual36.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/109579/1/Manual39.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/128124/2/59f8c07c55a4552db8db85044cfebee6.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/119881/1/LIPS_Zim_pp.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/122558/1/ProjectInnovationSummary-Wheat-P1327-I1438.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/114250/1/Policy_Brief_32.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/115699/1/Policy_Brief_34.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/116186/1/Gebregziabher_ESAP.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/123650/1/ProjectInnovationSummary-Maize-P961-I475.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/123650/1/ProjectInnovationSummary-Maize-P961-I475.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/123650/1/ProjectInnovationSummary-Maize-P961-I475.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/116772/4/GENDER_MOZAMBIQUE_online%20CGSpace.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/122784/1/ProjectInnovationSummary-A4NH-P345-I2146.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/122101/1/ProjectInnovationSummary-PIM-P596-I2774.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/114559/1/fss_livestock_decisions_Jacobo.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/121505/1/OutcomesCaseStudySummary-Livestock-P573-OICS3164.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/121502/1/OutcomesCaseStudySummary-Livestock-P573-OICS3091.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/126274/2/living_lab4people_low-emissionFoodSystem.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127817/1/FacilitationGuide.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/119791/4/AICCRA_PRM.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/125651/1/SAPLING_VIetnamAI.pptx
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/125346/1/U22ArtTamoIPMInthomDev.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/125901/1/UUScalingHub.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/126416/2/ESAAgribusinessSupportLandscape.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/117701/1/RR91.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/116821/1/RR88.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/113988/1/SDC%20Narravie%20Report%20%202015-%202021%20April%202021.pdf
# response code:  200
# url:  https://vlibrary.iwmi.org/pdf/H050804.pdf
# response code:  200
# url:  https://www.iwmi.cgiar.org/tools/sip-sizing-tool/sip_sizing_manual.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/128496/1/DST%20summary%20report_CIP_Nov%2022_22%20%281%29.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/125562/1/U22ArtMannersLeveragingInthomDev.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/126091/1/fclim-04-938975.pdf
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/127239/1/Reymondin%20%282022%29%20-%20Satellite-based%20tracking%20of%20agricultural%20adaptation%20--%20Technical%20Report.pdf
# response code:  200
# url:  https://www.iwmi.cgiar.org/2022/12/satisfying-the-growing-need-for-water-storage-the-role-of-sand-dams-in-an-integrated-storage-framework/
# response code:  200
# url:  https://www.iwmi.cgiar.org/2023/01/tributary-level-cooperation-in-the-isfayramsai-river-basin-can-benefit-kyrgyzstan-uzbekistan-and-the-aral-sea/
# response code:  200
# url:  https://cgspace.cgiar.org/bitstream/10568/126423/2/IP_ShambaShapeUp.pdf
# response code:  200
# 0      None
# 1      None
# 2      None
# 3      None
# 4      None
#        ...
# 121    None
# 122    None
# 123    None
# 124    None
# 125    None
# Length: 126, dtype: object
